# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement (3).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')
plt.ylabel('package (in LPA)')
# Out:
# Text(0, 0.5, 'package (in LPA)')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train, lr.predict(x_train), color='red')
plt.xlabel('cgpa')
plt.ylabel('package (in LPA)')
# Out:
# Text(0, 0.5, 'package (in LPA)')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error

# %%
y_pred = lr.predict(x_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE", mean_squared_error(y_test, y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE", root_mean_squared_error(y_test, y_pred))
# Out:
# RMSE 0.34827051717731616

# %%
print("RMSE",np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("R2", r2_score(y_test, y_pred))
# Out:
# R2 0.780730147510384

# %%
r2 = r2_score(y_test, y_pred)

# %%
#adjusted R2 score
x_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %%
new_df1 = df.copy()
new_df1['loda_lassan'] = np.random.random(200)

new_df1 = new_df1[['cgpa', 'loda_lassan', 'package']]
new_df1.head()
# Out:
#    cgpa  loda_lassan  package
# 0  6.89     0.275358     3.26
# 1  5.12     0.405156     1.98
# 2  7.82     0.786600     3.25
# 3  7.42     0.871117     3.67
# 4  6.94     0.881586     3.57

# %%
plt.scatter(new_df1['loda_lassan'], new_df1['package'])
plt.xlabel('loda_lassan')
plt.ylabel('package (in LPA)')
# Out:
# Text(0, 0.5, 'package (in LPA)')

# %%
x = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print("R2_score", r2_score(y_test,y_pred))
# Out:
# R2_score 0.7781690154690704

# %%
r2 = r2_score(y_test,y_pred)

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7661781514403715

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)
new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 85   4.79  1.38     1.48
# 192  8.25  4.45     3.75
# 19   7.48  3.83     2.83
# 128  7.93  2.84     3.34
# 99   6.61  3.64     3.24

# %%
plt.scatter(new_df2['iq'], new_df2['package'])
plt.xlabel('iq')
plt.ylabel('package (in LPA)')
# Out:
# Text(0, 0.5, 'package (in LPA)')

# %%
np.random.randint(-100,100)
# Out:
# 73

# %%
x = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=2)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)

# %%
print("r2_score", r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# r2_score 0.7992071553937558

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7883534881177425
